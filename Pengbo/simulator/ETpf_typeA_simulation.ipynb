# %%
import sys
sys.path.append('../../../')
sys.dont_write_bytecode = True
from lvdtsimulations.Kumar.modules.femm_simulation import Position_sensor

# %%
analytical = Position_sensor(sensor_type=['VC_fields'], 
                             save=True, 
                             sim_range={'steps_size_offset':[[1,1,0]]},
                             data = {'filename(s)':'fields',#['./data/TypeA_field_N40low_0A_10mm'], 
                                     'is default':['yes'], 
                                     'design or parameter':['A_1']},
                             mat_prop=['32 AWG_AI','31 AWG_AO','N40_low'])
analytical.execute(input_current=[0,0,[0,0]])
# Out:
# vc_analytical
# None
# coil config - [Coil_OutRadius, Coil_LowEnd, Coil_UppEnd, Coil_NrWind_p_Layer, Coil_NrWindings, Circuit_name]
# inner coil config : [12.494, -12.0, 12.0, 96.3855421686747, 578.3132530120482, 'InnCoil_Circuit']
# upper outer coil config : [36.96, 20.5, 34.0, 48.21428571428571, 337.49999999999994, 'UppOutCoil_Circuit']
# lower out coil config : [36.96, -34.0, -20.5, 48.21428571428571, 337.49999999999994, 'LowOutCoil_Circuit']
# inner coil material -  32 AWG_AI , outer coil material -  31 AWG_AO , magnet material -  N40_low
# inner, upper outer, total coil lengths :  42232.0893875825 76001.40947564426 194234.90833887103
# inner, upper outer coil Dc resistance as per datasheet (in ohms) : 22.446189241431643 32.63971292769631
# coil position (from centre) :  0
# coil position (from centre) :  1
# semi-analytical
# semi analytical force : [0.0, 0.0]
# femm force: [-0.00017202  0.00012838]

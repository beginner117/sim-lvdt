# %%
import numpy as np  
import matplotlib.pyplot as plt
import scienceplots
# %config InlineBackend.figure_format = 'svg'
plt.style.use(['science', 'notebook','grid'])

# %%
pos1 = np.array([0, 10, 20, 30, 40, 50])    
Bfield1 = np.array([36, 18.4, 8.6, 4.5, 2.4, 1.2])

pos2 = np.array([0,1,2,3,4,5])
Bfield2 = np.array([36, 32.3, 30.2, 28.4, 26.2, 24.6])

exp_pos1 = np.array([0, 5, 10, 15, 20])
exp_Bfield1 = np.array([30.9, 23.9, 15.6, 10.6, 7.4])

mat_955_pos1 = np.array([0, 5, 10, 15, 20])
mat_955_Bfield1 = np.array([29.9, 22.4, 15.9, 11.2, 7.9])

mat_860_pos1 = np.array([0, 5, 10, 15, 20])
mat_860_Bfield1 = np.array([27.0, 20.2, 14.3, 10.1, 7.1])

plt.plot(exp_pos1+8, exp_Bfield1, '*-', label='experiment')
plt.fill_between(exp_pos1+8, mat_860_Bfield1, mat_955_Bfield1, alpha=0.5, label='MATLAB N40 860-955')
plt.xlabel('Position away from the center of the magnet (cm)')
plt.ylabel('Magnetic Field (mT)')
plt.legend()
plt.title('Magnetic Field vs Position')
# Out:
# Text(0.5, 1.0, 'Magnetic Field vs Position')
